# %%
# default_exp utils

# %% [markdown]
# # Determine formats : neo4j_httpapi, neo4j_parsed, neo4j_downloaded, cyto

# %%
#hide
from nbdev.showdoc import *

# %%
#export
import json
from numpy import nan as NaN
false=False
def is_neo4j_httpapi_format(obj):
    if type(obj) != dict:
        return False
    if 'results' not in obj:
        return False
    return True

def is_neo4j_parsed_format(obj):
    if type(obj) != dict:
        return False
    if 'nodes' not in obj or 'edges' not in obj:
        return False
    if 'identifier' not in obj['nodes'][0]:
        return False
    return True

def is_cytoscape_format(obj):
    if type(obj) != dict:
        return False
    if 'nodes' not in obj or 'edges' not in obj:
        return False
    if 'data' not in obj['nodes'][0]:
        return False
    return True

def is_neo4j_downloaded_format(obj):
    if type(obj) != list:
        return False
    
    for _, item in obj[0].items():
        keys=item.keys()
        for k in ['start', 'end', 'segments', 'length']:
            if k not in keys:
                return False
            
    return True

# %%
neo4j_httpapi_json={
    "results": [
      {
        "columns": [
          "p"
        ],
        "data": [
          {
            "row": [
              [
                {
                  "identifier": "1",
                  "synonyms": "A1B|ABG|GAB|HYST2477",
                  "chromosome": "19",
                  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
                  "description": "alpha-1-B glycoprotein",
                  "source": "Entrez Gene:20220425",
                  "ensembl_id": "ENSG00000121410",
                  "uniprot_id": "P04217;V9HWD8",
                  "url": "http://identifiers.org/ncbigene/1",
                  "license": "CCO 1.0",
                  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
                  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
                  "name": "A1BG",
                  "location": "Secreted(uniprot)"
                },
                {
                  "license": "CC By 4.0",
                  "unbiased": "False",
                  "is_directional": "True",
                  "source": "NCBI gene2go:2021-02-01"
                },
                {
                  "identifier": "GO:0003674",
                  "license": "CC BY 4.0",
                  "name": "molecular_function",
                  "source": "Gene Ontology:2021-02-01",
                  "url": "http://purl.obolibrary.org/obo/GO:0003674"
                }
              ]
            ],
            "meta": [
              [
                {
                  "id": 2108,
                  "type": "node",
                  "deleted": false
                },
                {
                  "id": 458434,
                  "type": "relationship",
                  "deleted": false
                },
                {
                  "id": 799,
                  "type": "node",
                  "deleted": false
                }
              ]
            ],
            "graph": {
              "nodes": [
                {
                  "id": "2108",
                  "labels": [
                    "Gene"
                  ],
                  "properties": {
                    "identifier": "1",
                    "synonyms": "A1B|ABG|GAB|HYST2477",
                    "chromosome": "19",
                    "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
                    "description": "alpha-1-B glycoprotein",
                    "source": "Entrez Gene:20220425",
                    "ensembl_id": "ENSG00000121410",
                    "uniprot_id": "P04217;V9HWD8",
                    "url": "http://identifiers.org/ncbigene/1",
                    "license": "CCO 1.0",
                    "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
                    "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
                    "name": "A1BG",
                    "location": "Secreted(uniprot)"
                  }
                },
                {
                  "id": "799",
                  "labels": [
                    "MolecularFunction"
                  ],
                  "properties": {
                    "identifier": "GO:0003674",
                    "license": "CC BY 4.0",
                    "name": "molecular_function",
                    "source": "Gene Ontology:2021-02-01",
                    "url": "http://purl.obolibrary.org/obo/GO:0003674"
                  }
                }
              ],
              "relationships": [
                {
                  "id": "458434",
                  "type": "PARTICIPATES_GpMF",
                  "startNode": "2108",
                  "endNode": "799",
                  "properties": {
                    "license": "CC By 4.0",
                    "unbiased": "False",
                    "is_directional": "True",
                    "source": "NCBI gene2go:2021-02-01"
                  }
                }
              ]
            }
          },
          {
            "row": [
              [
                {
                  "identifier": "1",
                  "synonyms": "A1B|ABG|GAB|HYST2477",
                  "chromosome": "19",
                  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
                  "description": "alpha-1-B glycoprotein",
                  "source": "Entrez Gene:20220425",
                  "ensembl_id": "ENSG00000121410",
                  "uniprot_id": "P04217;V9HWD8",
                  "url": "http://identifiers.org/ncbigene/1",
                  "license": "CCO 1.0",
                  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
                  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
                  "name": "A1BG",
                  "location": "Secreted(uniprot)"
                },
                {
                  "license": "CCO 1.0",
                  "name": "IL6-mediated signaling events",
                  "is_directional": "False",
                  "source": "PID via Pathway Commons:v12"
                },
                {
                  "identifier": "PC12_4537",
                  "license": "CCO 1.0",
                  "genes": "{'2353', '7297', '1051', '9846', '1432', '7184', '6654', '2', '7409', '1401', '207', '5791', '3717', '3659', '8600', '4286', '598', '3716', '2549', '5295', '4609', '5580', '3725', '2266', '5879', '8543', '3726', '7076', '3929', '3569', '1052', '4170', '6772', '8554', '2308', '10401', '6416', '3055', '6774', '2885', '5600', '1', '5290', '5608', '9021', '3572', '3570', '5781', None}",
                  "name": "IL6-mediated signaling events",
                  "source": "PID via Pathway Commons:v12",
                  "url": "http://pathwaycommons.org/pc12/Pathway_51c26f89ab424243144fc1bed2dbd85f"
                }
              ]
            ],
            "meta": [
              [
                {
                  "id": 2108,
                  "type": "node",
                  "deleted": false
                },
                {
                  "id": 405645,
                  "type": "relationship",
                  "deleted": false
                },
                {
                  "id": 14482,
                  "type": "node",
                  "deleted": false
                }
              ]
            ],
            "graph": {
              "nodes": [
                {
                  "id": "14482",
                  "labels": [
                    "Pathway"
                  ],
                  "properties": {
                    "identifier": "PC12_4537",
                    "license": "CCO 1.0",
                    "genes": "{'2353', '7297', '1051', '9846', '1432', '7184', '6654', '2', '7409', '1401', '207', '5791', '3717', '3659', '8600', '4286', '598', '3716', '2549', '5295', '4609', '5580', '3725', '2266', '5879', '8543', '3726', '7076', '3929', '3569', '1052', '4170', '6772', '8554', '2308', '10401', '6416', '3055', '6774', '2885', '5600', '1', '5290', '5608', '9021', '3572', '3570', '5781', None}",
                    "name": "IL6-mediated signaling events",
                    "source": "PID via Pathway Commons:v12",
                    "url": "http://pathwaycommons.org/pc12/Pathway_51c26f89ab424243144fc1bed2dbd85f"
                  }
                },
                {
                  "id": "2108",
                  "labels": [
                    "Gene"
                  ],
                  "properties": {
                    "identifier": "1",
                    "synonyms": "A1B|ABG|GAB|HYST2477",
                    "chromosome": "19",
                    "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
                    "description": "alpha-1-B glycoprotein",
                    "source": "Entrez Gene:20220425",
                    "ensembl_id": "ENSG00000121410",
                    "uniprot_id": "P04217;V9HWD8",
                    "url": "http://identifiers.org/ncbigene/1",
                    "license": "CCO 1.0",
                    "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
                    "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
                    "name": "A1BG",
                    "location": "Secreted(uniprot)"
                  }
                }
              ],
              "relationships": [
                {
                  "id": "405645",
                  "type": "PARTICIPATES_GpPW",
                  "startNode": "2108",
                  "endNode": "14482",
                  "properties": {
                    "license": "CCO 1.0",
                    "name": "IL6-mediated signaling events",
                    "is_directional": "False",
                    "source": "PID via Pathway Commons:v12"
                  }
                }
              ]
            }
          },
          {
            "row": [
              [
                {
                  "identifier": "1",
                  "synonyms": "A1B|ABG|GAB|HYST2477",
                  "chromosome": "19",
                  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
                  "description": "alpha-1-B glycoprotein",
                  "source": "Entrez Gene:20220425",
                  "ensembl_id": "ENSG00000121410",
                  "uniprot_id": "P04217;V9HWD8",
                  "url": "http://identifiers.org/ncbigene/1",
                  "license": "CCO 1.0",
                  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
                  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
                  "name": "A1BG",
                  "location": "Secreted(uniprot)"
                },
                {
                  "sources": "hetio:v1",
                  "unbiased": "False",
                  "is_directional": "False"
                },
                {
                  "identifier": "80854",
                  "synonyms": "KMT7|SET7|SET7/9|SET9",
                  "chromosome": "4",
                  "xrefs": "MIM:606594|HGNC:HGNC:30412|Ensembl:ENSG00000145391|AllianceGenome:HGNC:30412",
                  "description": "SET domain containing 7, histone lysine methyltransferase",
                  "source": "Entrez Gene:20220425",
                  "ensembl_id": "ENSG00000145391",
                  "uniprot_id": "Q8WTS6;B5MCZ8;D6RJA0",
                  "url": "http://identifiers.org/ncbigene/80854",
                  "pdb": "3CBP;2F69;3CBO;1MT6;3M58;3CBM;3M5A;3M53;4E47;3M59;1H3I;3VUZ;1N6A;4J83;4J7I;1XQH;3M56;3VV0;1N6C;4J7F;5YLT;5EG2;5AYF;4JDS;3M57;4JLG;4J8O;3OS5;3M55;1O9S;1MUF;3M54",
                  "license": "CCO 1.0",
                  "url3": "https://genetics.opentargets.org/gene/ENSG00000145391",
                  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=SETD7",
                  "name": "SETD7",
                  "location": "Nucleus(uniprot);Chromosome(uniprot);Nucleoli(HPA_main);Nucleoli rim(HPA_main);Mitotic chromosome(HPA_additional)"
                }
              ]
            ],
            "meta": [
              [
                {
                  "id": 2108,
                  "type": "node",
                  "deleted": false
                },
                {
                  "id": 1933789,
                  "type": "relationship",
                  "deleted": false
                },
                {
                  "id": 81481,
                  "type": "node",
                  "deleted": false
                }
              ]
            ],
            "graph": {
              "nodes": [
                {
                  "id": "81481",
                  "labels": [
                    "Gene"
                  ],
                  "properties": {
                    "identifier": "80854",
                    "synonyms": "KMT7|SET7|SET7/9|SET9",
                    "chromosome": "4",
                    "xrefs": "MIM:606594|HGNC:HGNC:30412|Ensembl:ENSG00000145391|AllianceGenome:HGNC:30412",
                    "description": "SET domain containing 7, histone lysine methyltransferase",
                    "source": "Entrez Gene:20220425",
                    "ensembl_id": "ENSG00000145391",
                    "uniprot_id": "Q8WTS6;B5MCZ8;D6RJA0",
                    "url": "http://identifiers.org/ncbigene/80854",
                    "pdb": "3CBP;2F69;3CBO;1MT6;3M58;3CBM;3M5A;3M53;4E47;3M59;1H3I;3VUZ;1N6A;4J83;4J7I;1XQH;3M56;3VV0;1N6C;4J7F;5YLT;5EG2;5AYF;4JDS;3M57;4JLG;4J8O;3OS5;3M55;1O9S;1MUF;3M54",
                    "license": "CCO 1.0",
                    "url3": "https://genetics.opentargets.org/gene/ENSG00000145391",
                    "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=SETD7",
                    "name": "SETD7",
                    "location": "Nucleus(uniprot);Chromosome(uniprot);Nucleoli(HPA_main);Nucleoli rim(HPA_main);Mitotic chromosome(HPA_additional)"
                  }
                },
                {
                  "id": "2108",
                  "labels": [
                    "Gene"
                  ],
                  "properties": {
                    "identifier": "1",
                    "synonyms": "A1B|ABG|GAB|HYST2477",
                    "chromosome": "19",
                    "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
                    "description": "alpha-1-B glycoprotein",
                    "source": "Entrez Gene:20220425",
                    "ensembl_id": "ENSG00000121410",
                    "uniprot_id": "P04217;V9HWD8",
                    "url": "http://identifiers.org/ncbigene/1",
                    "license": "CCO 1.0",
                    "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
                    "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
                    "name": "A1BG",
                    "location": "Secreted(uniprot)"
                  }
                }
              ],
              "relationships": [
                {
                  "id": "1933789",
                  "type": "INTERACTS_GiG",
                  "startNode": "2108",
                  "endNode": "81481",
                  "properties": {
                    "sources": "hetio:v1",
                    "unbiased": "False",
                    "is_directional": "False"
                  }
                }
              ]
            }
          }
        ]
      }
    ],
    "errors": []
}

# %%
neo4j_parsed_json={
    "nodes": [
        {
            "identifier": "9429",
            "name": "ABCG2",
            "label": "Gene"
        },
        {
            "identifier": "DOID:0080199",
            "name": "colorectal carcinoma",
            "label": "Disease"
        },
        {
            "identifier": "7124",
            "name": "TNF",
            "label": "Gene"
        },
        {
            "identifier": "DB12010",
            "name": "Fostamatinib",
            "label": "Compound"
        },
        {
            "identifier": "2099",
            "name": "ESR1",
            "label": "Gene"
        },
        {
            "identifier": "2034",
            "name": "EPAS1",
            "label": "Gene"
        },
        {
            "identifier": "5468",
            "name": "PPARG",
            "label": "Gene"
        },
        {
            "identifier": "3091",
            "name": "HIF1A",
            "label": "Gene"
        },
        {
            "identifier": "405",
            "name": "ARNT",
            "label": "Gene"
        },
        {
            "identifier": "367",
            "name": "AR",
            "label": "Gene"
        },
        {
            "identifier": "140",
            "name": "ADORA3",
            "label": "Gene"
        },
        {
            "identifier": "50943",
            "name": "FOXP3",
            "label": "Gene"
        },
        {
            "identifier": "4318",
            "name": "MMP9",
            "label": "Gene"
        }
    ],
    "edges": [
        {
            "type": "BINDS_CbG",
            "start_identifier": "DB12010",
            "start_name": "Fostamatinib",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "is_directional": "True"
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "7124",
            "start_name": "TNF",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "is_directional": "True"
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "7124",
            "end_name": "TNF",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "2099",
            "end_name": "ESR1",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "2099",
            "start_name": "ESR1",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "P03372",
            "is_negative_regulation": "True",
            "consensus_direction": "False",
            "uniprot_id_trgt": "Q9UNQ0",
            "n_primary_sources": 0.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "PAZAR_DoRothEA;TRRUST_DoRothEA",
            "consensus_stimulation": "False",
            "is_positive_regulation": "False",
            "curation_effort": "1",
            "n_sources": 2.0,
            "n_references": 0.0,
            "category": "transcriptional",
            "license": NaN,
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "2034",
            "start_name": "EPAS1",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "Q99814",
            "is_negative_regulation": "False",
            "consensus_direction": "True",
            "uniprot_id_trgt": "Q9UNQ0",
            "n_primary_sources": 1.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "Wang",
            "consensus_stimulation": "True",
            "is_positive_regulation": "True",
            "curation_effort": "0",
            "n_sources": 1.0,
            "n_references": 0.0,
            "category": "post_translational",
            "license": NaN,
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "2034",
            "end_name": "EPAS1",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "5468",
            "start_name": "PPARG",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "P37231",
            "is_negative_regulation": "False",
            "consensus_direction": "True",
            "uniprot_id_trgt": "Q9UNQ0",
            "n_primary_sources": 0.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "ARACNe-GTEx_DoRothEA;TRRUST_DoRothEA",
            "consensus_stimulation": "True",
            "is_positive_regulation": "True",
            "curation_effort": "1",
            "n_sources": 2.0,
            "n_references": 0.0,
            "category": "transcriptional",
            "license": NaN,
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "5468",
            "end_name": "PPARG",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "3091",
            "start_name": "HIF1A",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "Q16665",
            "is_negative_regulation": "False",
            "consensus_direction": "True",
            "uniprot_id_trgt": "Q9UNQ0",
            "n_primary_sources": 1.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "Wang",
            "consensus_stimulation": "True",
            "is_positive_regulation": "True",
            "curation_effort": "0",
            "n_sources": 1.0,
            "n_references": 0.0,
            "category": "post_translational",
            "license": NaN,
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "3091",
            "end_name": "HIF1A",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "405",
            "end_name": "ARNT",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "405",
            "start_name": "ARNT",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "P27540",
            "is_negative_regulation": "False",
            "consensus_direction": "True",
            "uniprot_id_trgt": "Q9UNQ0",
            "n_primary_sources": 1.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "Wang",
            "consensus_stimulation": "True",
            "is_positive_regulation": "True",
            "curation_effort": "0",
            "n_sources": 1.0,
            "n_references": 0.0,
            "category": "post_translational",
            "license": NaN,
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "367",
            "start_name": "AR",
            "end_identifier": "9429",
            "end_name": "ABCG2",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "P10275",
            "is_negative_regulation": "False",
            "consensus_direction": "False",
            "uniprot_id_trgt": "Q9UNQ0",
            "n_primary_sources": 1.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "HTRIdb",
            "consensus_stimulation": "False",
            "is_positive_regulation": "False",
            "curation_effort": "1",
            "n_sources": 1.0,
            "n_references": 1.0,
            "category": "transcriptional",
            "license": NaN,
            "references": "HTRIdb:20610535",
            "references_stripped": "20610535",
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "367",
            "end_name": "AR",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "50943",
            "end_name": "FOXP3",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "BINDS_CbG",
            "start_identifier": "DB12010",
            "start_name": "Fostamatinib",
            "end_identifier": "140",
            "end_name": "ADORA3",
            "sources": "DrugBank (target):5.1.8",
            "unbiased": "False",
            "is_directional": "True",
            "actions": "antagonist",
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": NaN,
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": "16946104;26516587"
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "50943",
            "start_name": "FOXP3",
            "end_identifier": "140",
            "end_name": "ADORA3",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "Q9BZS1",
            "is_negative_regulation": "False",
            "consensus_direction": "False",
            "uniprot_id_trgt": "P0DMS8",
            "n_primary_sources": 1.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "HTRIdb",
            "consensus_stimulation": "False",
            "is_positive_regulation": "False",
            "curation_effort": "1",
            "n_sources": 1.0,
            "n_references": 1.0,
            "category": "transcriptional",
            "license": NaN,
            "references": "HTRIdb:20554955",
            "references_stripped": "20554955",
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "367",
            "start_name": "AR",
            "end_identifier": "140",
            "end_name": "ADORA3",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "P10275",
            "is_negative_regulation": "False",
            "consensus_direction": "False",
            "uniprot_id_trgt": "P0DMS8",
            "n_primary_sources": 1.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "HTRIdb",
            "consensus_stimulation": "False",
            "is_positive_regulation": "False",
            "curation_effort": "1",
            "n_sources": 1.0,
            "n_references": 1.0,
            "category": "transcriptional",
            "license": NaN,
            "references": "HTRIdb:20610535",
            "references_stripped": "20610535",
            "pubmed_ids": NaN
        },
        {
            "type": "INTERACTS_GiG5",
            "start_identifier": "140",
            "start_name": "ADORA3",
            "end_identifier": "4318",
            "end_name": "MMP9",
            "sources": NaN,
            "unbiased": NaN,
            "is_directional": "True",
            "actions": NaN,
            "uniprot_id_src": "P0DMS8",
            "is_negative_regulation": "False",
            "consensus_direction": "True",
            "uniprot_id_trgt": "P14780",
            "n_primary_sources": 1.0,
            "consensus_inhibition": "False",
            "source": "omnipath:20220113",
            "original_sources": "Wang",
            "consensus_stimulation": "True",
            "is_positive_regulation": "True",
            "curation_effort": "0",
            "n_sources": 1.0,
            "n_references": 0.0,
            "category": "post_translational",
            "license": NaN,
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        },
        {
            "type": "ASSOCIATES_DaG",
            "start_identifier": "DOID:0080199",
            "start_name": "colorectal carcinoma",
            "end_identifier": "4318",
            "end_name": "MMP9",
            "sources": "DisGeNET:v7.0",
            "unbiased": "True",
            "is_directional": "False",
            "actions": NaN,
            "uniprot_id_src": NaN,
            "is_negative_regulation": NaN,
            "consensus_direction": NaN,
            "uniprot_id_trgt": NaN,
            "n_primary_sources": NaN,
            "consensus_inhibition": NaN,
            "source": NaN,
            "original_sources": NaN,
            "consensus_stimulation": NaN,
            "is_positive_regulation": NaN,
            "curation_effort": NaN,
            "n_sources": NaN,
            "n_references": NaN,
            "category": NaN,
            "license": "CC BY-NC-SA 4.0",
            "references": NaN,
            "references_stripped": NaN,
            "pubmed_ids": NaN
        }
    ]
}

# %%
neo4j_downloaded_json=[
    {
      "p": {
  "start": {
  "identity": 2108,
  "labels": [
            "Gene"
          ],
  "properties": {
  "identifier": "1",
  "synonyms": "A1B|ABG|GAB|HYST2477",
  "chromosome": "19",
  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
  "description": "alpha-1-B glycoprotein",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000121410",
  "uniprot_id": "P04217;V9HWD8",
  "url": "http://identifiers.org/ncbigene/1",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
  "name": "A1BG",
  "location": "Secreted(uniprot)"
          }
        },
  "end": {
  "identity": 799,
  "labels": [
            "MolecularFunction"
          ],
  "properties": {
  "identifier": "GO:0003674",
  "license": "CC BY 4.0",
  "name": "molecular_function",
  "source": "Gene Ontology:2021-02-01",
  "url": "http://purl.obolibrary.org/obo/GO:0003674"
          }
        },
  "segments": [
          {
            "start": {
  "identity": 2108,
  "labels": [
                "Gene"
              ],
  "properties": {
  "identifier": "1",
  "synonyms": "A1B|ABG|GAB|HYST2477",
  "chromosome": "19",
  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
  "description": "alpha-1-B glycoprotein",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000121410",
  "uniprot_id": "P04217;V9HWD8",
  "url": "http://identifiers.org/ncbigene/1",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
  "name": "A1BG",
  "location": "Secreted(uniprot)"
              }
            },
            "relationship": {
  "identity": 458434,
  "start": 2108,
  "end": 799,
  "type": "PARTICIPATES_GpMF",
  "properties": {
  "license": "CC By 4.0",
  "unbiased": "False",
  "is_directional": "True",
  "source": "NCBI gene2go:2021-02-01"
              }
            },
            "end": {
  "identity": 799,
  "labels": [
                "MolecularFunction"
              ],
  "properties": {
  "identifier": "GO:0003674",
  "license": "CC BY 4.0",
  "name": "molecular_function",
  "source": "Gene Ontology:2021-02-01",
  "url": "http://purl.obolibrary.org/obo/GO:0003674"
              }
            }
          }
        ],
  "length": 1.0
      }
    },
    {
      "p": {
  "start": {
  "identity": 2108,
  "labels": [
            "Gene"
          ],
  "properties": {
  "identifier": "1",
  "synonyms": "A1B|ABG|GAB|HYST2477",
  "chromosome": "19",
  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
  "description": "alpha-1-B glycoprotein",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000121410",
  "uniprot_id": "P04217;V9HWD8",
  "url": "http://identifiers.org/ncbigene/1",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
  "name": "A1BG",
  "location": "Secreted(uniprot)"
          }
        },
  "end": {
  "identity": 14482,
  "labels": [
            "Pathway"
          ],
  "properties": {
  "identifier": "PC12_4537",
  "license": "CCO 1.0",
  "genes": "{'2353', '7297', '1051', '9846', '1432', '7184', '6654', '2', '7409', '1401', '207', '5791', '3717', '3659', '8600', '4286', '598', '3716', '2549', '5295', '4609', '5580', '3725', '2266', '5879', '8543', '3726', '7076', '3929', '3569', '1052', '4170', '6772', '8554', '2308', '10401', '6416', '3055', '6774', '2885', '5600', '1', '5290', '5608', '9021', '3572', '3570', '5781', None}",
  "name": "IL6-mediated signaling events",
  "source": "PID via Pathway Commons:v12",
  "url": "http://pathwaycommons.org/pc12/Pathway_51c26f89ab424243144fc1bed2dbd85f"
          }
        },
  "segments": [
          {
            "start": {
  "identity": 2108,
  "labels": [
                "Gene"
              ],
  "properties": {
  "identifier": "1",
  "synonyms": "A1B|ABG|GAB|HYST2477",
  "chromosome": "19",
  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
  "description": "alpha-1-B glycoprotein",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000121410",
  "uniprot_id": "P04217;V9HWD8",
  "url": "http://identifiers.org/ncbigene/1",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
  "name": "A1BG",
  "location": "Secreted(uniprot)"
              }
            },
            "relationship": {
  "identity": 405645,
  "start": 2108,
  "end": 14482,
  "type": "PARTICIPATES_GpPW",
  "properties": {
  "license": "CCO 1.0",
  "name": "IL6-mediated signaling events",
  "is_directional": "False",
  "source": "PID via Pathway Commons:v12"
              }
            },
            "end": {
  "identity": 14482,
  "labels": [
                "Pathway"
              ],
  "properties": {
  "identifier": "PC12_4537",
  "license": "CCO 1.0",
  "genes": "{'2353', '7297', '1051', '9846', '1432', '7184', '6654', '2', '7409', '1401', '207', '5791', '3717', '3659', '8600', '4286', '598', '3716', '2549', '5295', '4609', '5580', '3725', '2266', '5879', '8543', '3726', '7076', '3929', '3569', '1052', '4170', '6772', '8554', '2308', '10401', '6416', '3055', '6774', '2885', '5600', '1', '5290', '5608', '9021', '3572', '3570', '5781', None}",
  "name": "IL6-mediated signaling events",
  "source": "PID via Pathway Commons:v12",
  "url": "http://pathwaycommons.org/pc12/Pathway_51c26f89ab424243144fc1bed2dbd85f"
              }
            }
          }
        ],
  "length": 1.0
      }
    },
    {
      "p": {
  "start": {
  "identity": 2108,
  "labels": [
            "Gene"
          ],
  "properties": {
  "identifier": "1",
  "synonyms": "A1B|ABG|GAB|HYST2477",
  "chromosome": "19",
  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
  "description": "alpha-1-B glycoprotein",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000121410",
  "uniprot_id": "P04217;V9HWD8",
  "url": "http://identifiers.org/ncbigene/1",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
  "name": "A1BG",
  "location": "Secreted(uniprot)"
          }
        },
  "end": {
  "identity": 81481,
  "labels": [
            "Gene"
          ],
  "properties": {
  "identifier": "80854",
  "synonyms": "KMT7|SET7|SET7/9|SET9",
  "chromosome": "4",
  "xrefs": "MIM:606594|HGNC:HGNC:30412|Ensembl:ENSG00000145391|AllianceGenome:HGNC:30412",
  "description": "SET domain containing 7, histone lysine methyltransferase",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000145391",
  "uniprot_id": "Q8WTS6;B5MCZ8;D6RJA0",
  "url": "http://identifiers.org/ncbigene/80854",
  "pdb": "3CBP;2F69;3CBO;1MT6;3M58;3CBM;3M5A;3M53;4E47;3M59;1H3I;3VUZ;1N6A;4J83;4J7I;1XQH;3M56;3VV0;1N6C;4J7F;5YLT;5EG2;5AYF;4JDS;3M57;4JLG;4J8O;3OS5;3M55;1O9S;1MUF;3M54",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000145391",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=SETD7",
  "name": "SETD7",
  "location": "Nucleus(uniprot);Chromosome(uniprot);Nucleoli(HPA_main);Nucleoli rim(HPA_main);Mitotic chromosome(HPA_additional)"
          }
        },
  "segments": [
          {
            "start": {
  "identity": 2108,
  "labels": [
                "Gene"
              ],
  "properties": {
  "identifier": "1",
  "synonyms": "A1B|ABG|GAB|HYST2477",
  "chromosome": "19",
  "xrefs": "MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410|AllianceGenome:HGNC:5",
  "description": "alpha-1-B glycoprotein",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000121410",
  "uniprot_id": "P04217;V9HWD8",
  "url": "http://identifiers.org/ncbigene/1",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000121410",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=A1BG",
  "name": "A1BG",
  "location": "Secreted(uniprot)"
              }
            },
            "relationship": {
  "identity": 1933789,
  "start": 2108,
  "end": 81481,
  "type": "INTERACTS_GiG",
  "properties": {
  "sources": "hetio:v1",
  "unbiased": "False",
  "is_directional": "False"
              }
            },
            "end": {
  "identity": 81481,
  "labels": [
                "Gene"
              ],
  "properties": {
  "identifier": "80854",
  "synonyms": "KMT7|SET7|SET7/9|SET9",
  "chromosome": "4",
  "xrefs": "MIM:606594|HGNC:HGNC:30412|Ensembl:ENSG00000145391|AllianceGenome:HGNC:30412",
  "description": "SET domain containing 7, histone lysine methyltransferase",
  "source": "Entrez Gene:20220425",
  "ensembl_id": "ENSG00000145391",
  "uniprot_id": "Q8WTS6;B5MCZ8;D6RJA0",
  "url": "http://identifiers.org/ncbigene/80854",
  "pdb": "3CBP;2F69;3CBO;1MT6;3M58;3CBM;3M5A;3M53;4E47;3M59;1H3I;3VUZ;1N6A;4J83;4J7I;1XQH;3M56;3VV0;1N6C;4J7F;5YLT;5EG2;5AYF;4JDS;3M57;4JLG;4J8O;3OS5;3M55;1O9S;1MUF;3M54",
  "license": "CCO 1.0",
  "url3": "https://genetics.opentargets.org/gene/ENSG00000145391",
  "url2": "https://www.genecards.org/cgi-bin/carddisp.pl?gene=SETD7",
  "name": "SETD7",
  "location": "Nucleus(uniprot);Chromosome(uniprot);Nucleoli(HPA_main);Nucleoli rim(HPA_main);Mitotic chromosome(HPA_additional)"
              }
            }
          }
        ],
  "length": 1.0
      }
    }
  ]

# %%
cyto_json={
    "nodes": [
        {"data": {"id": "A", "name": "A", "label": "Gene"}},
        {"data": {"id": "B", "name": "Very_long_name", "label": "Disease"}},
        {"data": {"id": "C", "name": "Much_more_long_name", "label": "Compound"}},
        {"data": {"id": "D", "name": "D", "label": "Gene"}}
    ],
    "edges": [
        {"data": {"source": "A", "target": "B", "type": "RELATION1", "is_directional": "True"}}, 
        {"data": {"source": "B", "target": "A", "type": "RELATION2", "is_directional": "True"}}, 
        {"data": {"source": "C", "target": "A", "type": "RELATION3", "is_directional": "True"}}, 
        {"data": {"source": "A", "target": "C", "type": "RELATION4", "is_directional": "True"}}, 
        {"data": {"source": "A", "target": "D", "type": "RELATION5", "is_directional": "False"}}, 
        {"data": {"source": "C", "target": "D", "type": "RELATION6", "is_directional": "True"}}, 
        {"data": {"source": "D", "target": "C", "type": "RELATION7", "is_directional": "True"}}, 
        {"data": {"source": "B", "target": "D", "type": "RELATION8", "is_directional": "True"}}, 
        {"data": {"source": "D", "target": "B", "type": "RELATION9", "is_directional": "True"}}
    ]
}

# %%
assert is_neo4j_httpapi_format(neo4j_httpapi_json)
assert not is_neo4j_httpapi_format(neo4j_downloaded_json)
assert not is_neo4j_httpapi_format(neo4j_parsed_json)
assert not is_neo4j_httpapi_format(cyto_json)

# %%
assert is_neo4j_parsed_format(neo4j_parsed_json)
assert not is_neo4j_parsed_format(neo4j_httpapi_json)
assert not is_neo4j_parsed_format(neo4j_downloaded_json)
assert not is_neo4j_parsed_format(cyto_json)

# %%
assert is_cytoscape_format(cyto_json)
assert not is_cytoscape_format(neo4j_parsed_json)
assert not is_cytoscape_format(neo4j_httpapi_json)
assert not is_cytoscape_format(neo4j_downloaded_json)

# %%
assert is_neo4j_downloaded_format(neo4j_downloaded_json)
assert not is_neo4j_downloaded_format(neo4j_parsed_json)
assert not is_neo4j_downloaded_format(neo4j_httpapi_json)
assert not is_neo4j_downloaded_format(cyto_json)
